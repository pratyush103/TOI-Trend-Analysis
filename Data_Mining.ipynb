# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: nltk in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: statsmodels in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 5)) (0.14.1)
# Requirement already satisfied: textblob in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 6)) (0.18.0.post0)
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 7)) (1.4.1.post1)
# Requirement already satisfied: xgboost in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 8)) (2.0.3)
# Requirement already satisfied: lightgbm in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 9)) (4.3.0)
# Collecting transformers (from -r requirements.txt (line 10))
#   Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#                                               0.0/8.5 MB ? eta -:--:--
#      ---                                      0.7/8.5 MB 14.2 MB/s eta 0:00:01
#      --------                                 1.8/8.5 MB 16.6 MB/s eta 0:00:01
#      -------------                            2.9/8.5 MB 16.8 MB/s eta 0:00:01
#      -----------------                        3.8/8.5 MB 17.3 MB/s eta 0:00:01
#      ---------------------                    4.7/8.5 MB 17.6 MB/s eta 0:00:01
#      --------------------------               5.6/8.5 MB 18.0 MB/s eta 0:00:01
#      ------------------------------           6.5/8.5 MB 18.1 MB/s eta 0:00:01
#      ------------------------------------     7.9/8.5 MB 17.9 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 18.2 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------  8.5/8.5 MB 17.6 MB/s eta 0:00:01
#      ---------------------------------------- 8.5/8.5 MB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: click in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk->-r requirements.txt (line 4)) (8.1.3)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk->-r requirements.txt (line 4)) (2023.3.23)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk->-r requirements.txt (line 4)) (4.65.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels->-r requirements.txt (line 5)) (1.10.1)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels->-r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: filelock in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers->-r requirements.txt (line 10)) (3.10.0)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers->-r requirements.txt (line 10))
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#                                               0.0/346.4 kB ? eta -:--:--
#      ------------------------------------- 346.4/346.4 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers->-r requirements.txt (line 10)) (6.0)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers->-r requirements.txt (line 10)) (2.28.2)
# Collecting tokenizers<0.19,>=0.14 (from transformers->-r requirements.txt (line 10))
#   Downloading tokenizers-0.15.2-cp310-none-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      ---------------------------------------  2.2/2.2 MB 23.2 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 23.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 9.3 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers->-r requirements.txt (line 10))
#   Downloading safetensors-0.4.2-cp310-none-win_amd64.whl (269 kB)
#                                               0.0/269.5 kB ? eta -:--:--
#      ---------------------------------------  266.2/269.5 kB ? eta -:--:--
#      ---------------------------------------  266.2/269.5 kB ? eta -:--:--
#      -------------------------------------- 269.5/269.5 kB 1.8 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.19.3->transformers->-r requirements.txt (line 10))
#   Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#                                               0.0/170.9 kB ? eta -:--:--
#      -------------------------------------- 170.9/170.9 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers->-r requirements.txt (line 10)) (4.5.0)
# Requirement already satisfied: six in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from patsy>=0.5.4->statsmodels->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->nltk->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers->-r requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers->-r requirements.txt (line 10)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers->-r requirements.txt (line 10)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->transformers->-r requirements.txt (line 10)) (2022.12.7)
# Installing collected packages: safetensors, fsspec, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.3.0
#     Uninstalling fsspec-2023.3.0:
#       Successfully uninstalled fsspec-2023.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.13.3
#     Uninstalling huggingface-hub-0.13.3:
#       Successfully uninstalled huggingface-hub-0.13.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\DELL\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima_model import ARIMA
import nltk
import re
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('vader_lexicon')
from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem.porter import PorterStemmer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import xgboost 
import lightgbm
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...

# %%
df_text = pd.read_csv("india-news-headlines.csv")
df_text.head()
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic
